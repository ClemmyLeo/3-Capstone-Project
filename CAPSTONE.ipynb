# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import mean_squared_error, explained_variance_score, max_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
import tensorflow as tf
import keras

# %%
#timestamp" - timestamp field for grouping the data
#"cnt" - the count of a new bike shares
#"t1" - real temperature in C
#"t2" - temperature in C "feels like"
#"hum" - humidity in percentage
#"windspeed" - wind speed in km/h
#"weathercode" - category of the weather
#"isholiday" - boolean field - 1 holiday / 0 non holiday
#"isweekend" - boolean field - 1 if the day is weekend
#"season" - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.

#"weathe_code" category description:
#1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity 2 = scattered clouds / few clouds 3 = Broken clouds 4 = Cloudy 7 = Rain/ light Rain shower/ Light rain 10 = rain with thunderstorm 26 = snowfall 94 = Freezing Fog

# %%
df = pd.read_csv("london_merged.csv", parse_dates = ['timestamp'])
df.tail()
# Out:
#                 timestamp   cnt   t1   t2   hum  wind_speed  weather_code  \
# 17409 2017-01-03 19:00:00  1042  5.0  1.0  81.0        19.0           3.0
# 17410 2017-01-03 20:00:00   541  5.0  1.0  81.0        21.0           4.0
# 17411 2017-01-03 21:00:00   337  5.5  1.5  78.5        24.0           4.0
# 17412 2017-01-03 22:00:00   224  5.5  1.5  76.0        23.0           4.0
# 17413 2017-01-03 23:00:00   139  5.0  1.0  76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0

# %%
df.shape
# Out:
# (17414, 10)

# %%
df.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %% [markdown]
# Splitting the Date & Time, Convert to datetime

# %%
#df[['Date','Time']] = df['timestamp'].str.split(' ', expand=True)

df["Year"] = df["timestamp"].dt.year
df['Month'] = df["timestamp"].dt.month
df["Dayofweek"] = df["timestamp"].dt.dayofweek
df["Hour"] = df["timestamp"].dt.hour
df.head()
df
# Out:
#                 timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0     2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1     2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2     2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3     2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4     2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...   ...  ...  ...    ...         ...           ...
# 17409 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season  Year  Month  Dayofweek  Hour
# 0             0.0         1.0     3.0  2015      1          6     0
# 1             0.0         1.0     3.0  2015      1          6     1
# 2             0.0         1.0     3.0  2015      1          6     2
# 3             0.0         1.0     3.0  2015      1          6     3
# 4             0.0         1.0     3.0  2015      1          6     4
# ...           ...         ...     ...   ...    ...        ...   ...
# 17409         0.0         0.0     3.0  2017      1          1    19
# 17410         0.0         0.0     3.0  2017      1          1    20
# 17411         0.0         0.0     3.0  2017      1          1    21
# 17412         0.0         0.0     3.0  2017      1          1    22
# 17413         0.0         0.0     3.0  2017      1          1    23
#
# [17414 rows x 14 columns]

# %%
index = df.set_index('timestamp', inplace=True)

# %%
plt.figure(figsize=(5,3))
pvt = pd.pivot_table(df , columns='Year', index='Month', aggfunc= 'sum', values='cnt')

pvt.plot(subplots=False, use_index=True)
plt.ticklabel_format(style='plain')

# %%
pvt
# Out:
# Year        2015       2016     2017
# Month
# 1       546639.0   582518.0  37680.0
# 2       543594.0   592910.0      NaN
# 3       695934.0   656527.0      NaN
# 4       831582.0   768845.0      NaN
# 5       895413.0  1001935.0      NaN
# 6      1033252.0   933878.0      NaN
# 7      1120687.0  1165527.0      NaN
# 8      1033951.0  1137314.0      NaN
# 9       892478.0   998619.0      NaN
# 10      865046.0   935706.0      NaN
# 11      677332.0   703859.0      NaN
# 12      602838.0   651908.0      NaN

# %%
temp = df['cnt']
temp.plot()
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
df.describe().T
# Out:
#                 count         mean          std     min     25%     50%  \
# cnt           17414.0  1143.101642  1085.108068     0.0   257.0   844.0
# t1            17414.0    12.468091     5.571818    -1.5     8.0    12.5
# t2            17414.0    11.520836     6.615145    -6.0     6.0    12.5
# hum           17414.0    72.324954    14.313186    20.5    63.0    74.5
# wind_speed    17414.0    15.913063     7.894570     0.0    10.0    15.0
# weather_code  17414.0     2.722752     2.341163     1.0     1.0     2.0
# is_holiday    17414.0     0.022051     0.146854     0.0     0.0     0.0
# is_weekend    17414.0     0.285403     0.451619     0.0     0.0     0.0
# season        17414.0     1.492075     1.118911     0.0     0.0     1.0
# Year          17414.0  2015.507810     0.508157  2015.0  2015.0  2016.0
# Month         17414.0     6.514643     3.452509     1.0     4.0     7.0
# Dayofweek     17414.0     2.992650     2.004060     0.0     1.0     3.0
# Hour          17414.0    11.513265     6.915893     0.0     6.0    12.0
#
#                   75%     max
# cnt           1671.75  7860.0
# t1              16.00    34.0
# t2              16.00    34.0
# hum             83.00   100.0
# wind_speed      20.50    56.5
# weather_code     3.00    26.0
# is_holiday       0.00     1.0
# is_weekend       1.00     1.0
# season           2.00     3.0
# Year          2016.00  2017.0
# Month           10.00    12.0
# Dayofweek        5.00     6.0
# Hour            18.00    23.0

# %%
# Some insights into the dataset

# Average Temp based on Mean is 12.5°C for real temp, 11.5°C for feel-like temp. 
# Max humudity at 100% seems very extreme
# Max windspeed at 56km/h means very strong winds. Walking is not easy with such high winds, unless its tail wind.

# %%
# Correlation Heatmap

plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),linewidths=0.1, 
            square=True,  linecolor='blue', annot=True)
plt.show()

# %%
# From the Heatmap above,
# Low correalation between Hum with cnt, t1, t2 and windspeed
# High correlation between t1 and t2, isweekend and dayofweek

# %%
sns.set(rc={'figure.figsize':(12,8.5)})
seasons = sns.barplot(x = 'Month', y='cnt', hue= 'season', data = df, estimator=sum).set(title='Monthly usage based on Season')
plt.ticklabel_format(style='plain', axis='y')
#seasons1 = {0: "Spring", 1:"Summer", 2:"Fall", 3:"Winter"}
#df['season'] = df['season'].map(seasons1)

# %%
#Count of bicycle monthly basis based on Season
x = df.groupby(["season","Month"])["cnt"].sum()
x
# Out:
# season  Month
# 0.0     3        1352461
#         4        1600427
#         5        1897348
# 1.0     6        1967130
#         7        2286214
#         8        2171265
# 2.0     9        1891097
#         10       1800752
#         11       1381191
# 3.0     1        1166837
#         2        1136504
#         12       1254746
# Name: cnt, dtype: int64

# %%
#Humidity

plt.figure(figsize=(15,5))
sns.pointplot(data=df, x=df.hum, y=df.cnt, color='Red')
plt.locator_params(axis='x', nbins=15)
plt.show()

# %%
# The feeling of humidity isnt very pleasant, as such, rentals decline as humidity goes up.

# %%
# Weather Usage

plt.figure(figsize=(15,5))
sns.histplot(data=df, x=df.weather_code, y=df.cnt)
plt.locator_params(axis='x', nbins=15)
plt.show()

# %%
# General trend is that the more intense the weather, the lesser the number of rentals.
# 1 - 3 shows clear to cloudy weather without rainfall.
# 4 - 26 depicts light to heavy precipitation.

# %%
# Windspeed

plt.figure(figsize=(25,5))
sns.barplot(data=df, x=df.wind_speed, y=df.cnt)
plt.locator_params(axis='x', nbins=15)
plt.show()

# %%
# Based on the general curve of the plot, windspeed of 25km/h garners the most riders.
# But looking at the curve, there are quite a number of outliers where those speeds jumps or drops drastically from its neighbours

# %%
plt.figure(figsize=(15,5))
sns.pointplot(data=df, x=df.Hour, y=df.cnt, hue=df.is_weekend)
plt.show()
plt.figure(figsize=(15,5))
sns.pointplot(data=df, x=df.Hour, y=df.cnt, hue=df.is_holiday)
plt.show()

# %%
# Comparitively, the hours of a holiday are vastly different from a non holiday.

# People generally sleep in and have a nice slow morning on holidays, 
# before being active in the late mornings onwards.
# Similarly , when it is holiday.

# %%
# Weekly Usage Patterns

plt.figure(figsize=(15,5))
sns.boxplot(data=df, x=df.Dayofweek, y=df.cnt)

plt.show()

# %%
# Mon to Wed has the highest days of usage with Wed peaking.
# Weekdays has much more usage/day as compared to weekends.

# I would suppose this might be a pattern in London, given that it is their thing to cycle to work and not use it that much over the weekend.
# It is the opposite scenario in my country.

# %%
#Change object to category data

df['weather_code'] = df['weather_code'].astype('category')
df['is_holiday'] = df['is_holiday'].astype('category')
df['is_weekend'] = df['is_weekend'].astype('category')
df['season'] = df['season'].astype('category')

df['Year'] = df['Year'].astype('category')
df['Month'] = df['Month'].astype('category')
df['Dayofweek'] = df['Dayofweek'].astype('category')
df['Hour'] = df['Hour'].astype('category')

#df.info()

# %% [markdown]
# ### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# Label Encoding

le = LabelEncoder()

columns = ['weather_code', 'is_holiday', 'is_weekend', 'season', 'Year', 'Month', 'Dayofweek', 'Hour']

for col in columns:
    le.fit(df[col])
    df[col] = le.transform(df[col])
    
df.head()
# Out:
#                      cnt   t1   t2    hum  wind_speed  weather_code  \
# timestamp
# 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0             2
# 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0             0
# 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0             0
# 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0             0
# 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5             0
#
#                      is_holiday  is_weekend  season  Year  Month  Dayofweek  \
# timestamp
# 2015-01-04 00:00:00           0           1       3     0      0          6
# 2015-01-04 01:00:00           0           1       3     0      0          6
# 2015-01-04 02:00:00           0           1       3     0      0          6
# 2015-01-04 03:00:00           0           1       3     0      0          6
# 2015-01-04 04:00:00           0           1       3     0      0          6
#
#                      Hour
# timestamp
# 2015-01-04 00:00:00     0
# 2015-01-04 01:00:00     1
# 2015-01-04 02:00:00     2
# 2015-01-04 03:00:00     3
# 2015-01-04 04:00:00     4

# %%
#Train-90% Test-10%

from sklearn.model_selection import train_test_split
#train,test = train_test_split(df,test_size=0.1,random_state=0)

#print('Train Size:' ,train.shape)
#print('Test Size:', test.shape)

# %%
from sklearn.model_selection import train_test_split

train_size = int(len(df) * 0.9)
test_size = len(df) - train_size
train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]
print(len(train), len(test))
# Out:
# 15672 1742

# %% [markdown]
# Scaler

# %%
from sklearn.preprocessing import RobustScaler
scaler  = RobustScaler()

num_colu = ['t1', 't2', 'hum', 'wind_speed']
trans_1 = scaler.fit(train[num_colu].to_numpy())
train.loc[:,num_colu] = trans_1.transform(train[num_colu].to_numpy())
test.loc[:,num_colu] = trans_1.transform(test[num_colu].to_numpy())

scaler2 = RobustScaler()
scaler2 = scaler2.fit(train[["cnt"]])
train["cnt"] = scaler2.transform(train[["cnt"]])
test["cnt"] = scaler2.transform(test[["cnt"]])

# %%
#cols = ['t1', 't2', 'hum', 'wind_speed']

#scaler = RobustScaler()
#scaler = scaler.fit(np.asarray(train[cols]))

#train.loc[:, cols] = scaler.transform(np.asarray(train[cols]))
#test.loc[:, cols] = scaler.transform(np.asarray(test[cols]))

#scaler2 = RobustScaler()
#scaler2 = scaler2.fit(train[['cnt']])
#train['cnt'] = scaler2.transform(train[['cnt']])
#test['cnt'] = scaler2.transform(test[['cnt']])

# %%
def create_dataset(x,y,time_steps=1):
    x_train,y_train = [],[]
    
    for i in range(len(x)-time_steps):
        v = x.iloc[i:(i+time_steps)].values
        x_train.append(v)
        y_train.append(y.iloc[i+time_steps])
        
    return np.array(x_train),np.array(y_train)

# %%
#[samples, time steps, features]
time_steps = 10

x_train,y_train = create_dataset(train,train.cnt,time_steps)
x_test,y_test = create_dataset(test,test.cnt,time_steps)

print(x_train.shape,y_train.shape)
# Out:
# (15662, 10, 13) (15662,)

# %%
tf.random.set_seed(0)

# %% [markdown]
# LSTM MODEL

# %%
model1 = tf.keras.Sequential()
model1.add(tf.keras.layers.LSTM(units=128, input_shape=(x_train.shape[1], x_train.shape[2])))
model1.add(tf.keras.layers.Dropout(rate=0.2))
model1.add(tf.keras.layers.Dense(units=1))
model1.compile(loss='mse', optimizer='adam')
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               72704
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 72,833
# Trainable params: 72,833
# Non-trainable params: 0
# 2022-12-31 15:24:16.099654: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# _________________________________________________________________

# %%
#cp = ModelCheckpoint('model1/', save_best_only=True)

# %%
lstm = model1.fit(x_train, y_train,epochs=50,batch_size=32,validation_split=0.1,shuffle=False)
# Out:
# Epoch 1/50
# 441/441 [==============================] - 4s 7ms/step - loss: 0.1566 - val_loss: 0.0873
# Epoch 2/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0681 - val_loss: 0.0642
# Epoch 3/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0449 - val_loss: 0.0610
# Epoch 4/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0358 - val_loss: 0.0549
# Epoch 5/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0318 - val_loss: 0.0477
# Epoch 6/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0277 - val_loss: 0.0438
# Epoch 7/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0243 - val_loss: 0.0383
# Epoch 8/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0221 - val_loss: 0.0379
# Epoch 9/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0206 - val_loss: 0.0311
# Epoch 10/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0195 - val_loss: 0.0284
# Epoch 11/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0193 - val_loss: 0.0369
# Epoch 12/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0179 - val_loss: 0.0321
# Epoch 13/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0175 - val_loss: 0.0246
# Epoch 14/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0173 - val_loss: 0.0238
# Epoch 15/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0168 - val_loss: 0.0238
# Epoch 16/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0162 - val_loss: 0.0265
# Epoch 17/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0160 - val_loss: 0.0238
# Epoch 18/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0156 - val_loss: 0.0240
# Epoch 19/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0154 - val_loss: 0.0227
# Epoch 20/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0147 - val_loss: 0.0270
# Epoch 21/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0149 - val_loss: 0.0208
# Epoch 22/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0149 - val_loss: 0.0246
# Epoch 23/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0146 - val_loss: 0.0218
# Epoch 24/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0139 - val_loss: 0.0256
# Epoch 25/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0142 - val_loss: 0.0204
# Epoch 26/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0139 - val_loss: 0.0237
# Epoch 27/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0137 - val_loss: 0.0196
# Epoch 28/50
# 441/441 [==============================] - 3s 7ms/step - loss: 0.0138 - val_loss: 0.0201
# Epoch 29/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0133 - val_loss: 0.0210
# Epoch 30/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0132 - val_loss: 0.0211
# Epoch 31/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0132 - val_loss: 0.0200
# Epoch 32/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0131 - val_loss: 0.0171
# Epoch 33/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0126 - val_loss: 0.0214
# Epoch 34/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0124 - val_loss: 0.0175
# Epoch 35/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0120 - val_loss: 0.0180
# Epoch 36/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0122 - val_loss: 0.0196
# Epoch 37/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0122 - val_loss: 0.0218
# Epoch 38/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0122 - val_loss: 0.0186
# Epoch 39/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0120 - val_loss: 0.0195
# Epoch 40/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0118 - val_loss: 0.0226
# Epoch 41/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0116 - val_loss: 0.0202
# Epoch 42/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0120 - val_loss: 0.0199
# Epoch 43/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0112 - val_loss: 0.0195
# Epoch 44/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0113 - val_loss: 0.0203
# Epoch 45/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0115 - val_loss: 0.0192
# Epoch 46/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0111 - val_loss: 0.0190
# Epoch 47/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0113 - val_loss: 0.0250
# Epoch 48/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0112 - val_loss: 0.0204
# Epoch 49/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0105 - val_loss: 0.0227
# Epoch 50/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0106 - val_loss: 0.0211

# %%
train_predictions = model1.predict(x_test)

y_train_inv = scaler2.inverse_transform(y_train.reshape(1, -1))
y_test_inv = scaler2.inverse_transform(y_test.reshape(1, -1))
train_pred_inv = scaler2.inverse_transform(train_predictions)

train_results = pd.DataFrame(data={'Train Predictions':train_pred_inv.flatten(), 'Actuals':y_test_inv.flatten()})
# Out:
# 55/55 [==============================] - 0s 3ms/step

# %%
train_results
# Out:
#       Train Predictions  Actuals
# 0           1525.811768   1376.0
# 1           1094.567627    894.0
# 2            706.372498    615.0
# 3            524.493408    462.0
# 4            400.057709    481.0
# ...                 ...      ...
# 1727        1422.105225   1042.0
# 1728         660.077332    541.0
# 1729         413.381287    337.0
# 1730         216.926025    224.0
# 1731         130.595764    139.0
#
# [1732 rows x 2 columns]

# %%
plt.plot(train_results['Train Predictions'][50:100])
plt.plot(train_results['Actuals'][50:100])

# %%
plt.plot(lstm.history['loss'], label='train')
plt.plot(lstm.history['val_loss'], label='validation')
plt.legend()
plt.show()

# %%
lstm_train_pred = model1.predict(x_train)
lstm_test_pred = model1.predict(x_test)
print('Train RMSE:', np.sqrt(mean_squared_error(y_train, lstm_train_pred)))
print('Test RMSE:', np.sqrt(mean_squared_error(y_test, lstm_test_pred)))
print('MSE:', mean_squared_error(y_test, train_predictions))
print('Explained variance score:', explained_variance_score(y_test, train_predictions))
print('Max error:', max_error(y_test, train_predictions))
# Out:
# 490/490 [==============================] - 1s 2ms/step
# 55/55 [==============================] - 0s 2ms/step
# Train RMSE: 0.11969177346313367
# Test RMSE: 0.15634960276049403
# MSE: 0.02444519828336428
# Explained variance score: 0.940909605485145
# Max error: 0.9557069976796132

# %% [markdown]
# GRU Model

# %%
model2 = tf.keras.Sequential()
model2.add(tf.keras.layers.GRU(units=128, input_shape=(x_train.shape[1], x_train.shape[2])))
model2.add(tf.keras.layers.Dropout(rate=0.2))
model2.add(tf.keras.layers.Dense(units=1))
model2.compile(loss='mean_squared_error', optimizer='adam')
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 128)               54912
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 55,041
# Trainable params: 55,041
# Non-trainable params: 0
# _________________________________________________________________

# %%
gru = model2.fit(x_train, y_train,epochs=50,batch_size=32,validation_split=0.1,shuffle=False)
# Out:
# Epoch 1/50
# 441/441 [==============================] - 4s 6ms/step - loss: 0.2251 - val_loss: 0.1041
# Epoch 2/50
# 441/441 [==============================] - 2s 5ms/step - loss: 0.0778 - val_loss: 0.0444
# Epoch 3/50
# 441/441 [==============================] - 2s 5ms/step - loss: 0.0421 - val_loss: 0.0401
# Epoch 4/50
# 441/441 [==============================] - 2s 5ms/step - loss: 0.0310 - val_loss: 0.0314
# Epoch 5/50
# 441/441 [==============================] - 2s 5ms/step - loss: 0.0260 - val_loss: 0.0312
# Epoch 6/50
# 441/441 [==============================] - 2s 5ms/step - loss: 0.0237 - val_loss: 0.0246
# Epoch 7/50
# 441/441 [==============================] - 2s 5ms/step - loss: 0.0213 - val_loss: 0.0229
# Epoch 8/50
# 441/441 [==============================] - 2s 5ms/step - loss: 0.0206 - val_loss: 0.0255
# Epoch 9/50
# 441/441 [==============================] - 2s 5ms/step - loss: 0.0195 - val_loss: 0.0208
# Epoch 10/50
# 441/441 [==============================] - 2s 5ms/step - loss: 0.0193 - val_loss: 0.0221
# Epoch 11/50
# 441/441 [==============================] - 2s 5ms/step - loss: 0.0190 - val_loss: 0.0211
# Epoch 12/50
# 441/441 [==============================] - 2s 5ms/step - loss: 0.0181 - val_loss: 0.0203
# Epoch 13/50
# 441/441 [==============================] - 2s 5ms/step - loss: 0.0178 - val_loss: 0.0200
# Epoch 14/50
# 441/441 [==============================] - 2s 5ms/step - loss: 0.0170 - val_loss: 0.0214
# Epoch 15/50
# 441/441 [==============================] - 2s 5ms/step - loss: 0.0161 - val_loss: 0.0209
# Epoch 16/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0159 - val_loss: 0.0209
# Epoch 17/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0161 - val_loss: 0.0215
# Epoch 18/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0155 - val_loss: 0.0232
# Epoch 19/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0156 - val_loss: 0.0232
# Epoch 20/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0148 - val_loss: 0.0224
# Epoch 21/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0152 - val_loss: 0.0230
# Epoch 22/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0147 - val_loss: 0.0212
# Epoch 23/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0146 - val_loss: 0.0231
# Epoch 24/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0143 - val_loss: 0.0243
# Epoch 25/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0145 - val_loss: 0.0219
# Epoch 26/50
# 441/441 [==============================] - 3s 6ms/step - loss: 0.0141 - val_loss: 0.0247
# Epoch 27/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0141 - val_loss: 0.0223
# Epoch 28/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0139 - val_loss: 0.0243
# Epoch 29/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0138 - val_loss: 0.0205
# Epoch 30/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0135 - val_loss: 0.0227
# Epoch 31/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0133 - val_loss: 0.0213
# Epoch 32/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0129 - val_loss: 0.0223
# Epoch 33/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0127 - val_loss: 0.0225
# Epoch 34/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0126 - val_loss: 0.0213
# Epoch 35/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0125 - val_loss: 0.0206
# Epoch 36/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0122 - val_loss: 0.0220
# Epoch 37/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0126 - val_loss: 0.0197
# Epoch 38/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0122 - val_loss: 0.0216
# Epoch 39/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0123 - val_loss: 0.0218
# Epoch 40/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0118 - val_loss: 0.0229
# Epoch 41/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0119 - val_loss: 0.0202
# Epoch 42/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0116 - val_loss: 0.0214
# Epoch 43/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0115 - val_loss: 0.0199
# Epoch 44/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0116 - val_loss: 0.0218
# Epoch 45/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0116 - val_loss: 0.0243
# Epoch 46/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0116 - val_loss: 0.0218
# Epoch 47/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0112 - val_loss: 0.0219
# Epoch 48/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0108 - val_loss: 0.0219
# Epoch 49/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0106 - val_loss: 0.0218
# Epoch 50/50
# 441/441 [==============================] - 2s 6ms/step - loss: 0.0110 - val_loss: 0.0193

# %%
train_predictions = model2.predict(x_test)

y_train_inv = scaler2.inverse_transform(y_train.reshape(1, -1))
y_test_inv = scaler2.inverse_transform(y_test.reshape(1, -1))
train_pred_inv = scaler2.inverse_transform(train_predictions)

train_results = pd.DataFrame(data={'Train Predictions':train_pred_inv.flatten(), 'Actuals':y_test_inv.flatten()})
# Out:
# 55/55 [==============================] - 0s 2ms/step

# %%
train_results
# Out:
#       Train Predictions  Actuals
# 0           1421.836426   1376.0
# 1            940.137573    894.0
# 2            585.289368    615.0
# 3            394.364990    462.0
# 4            295.243469    481.0
# ...                 ...      ...
# 1727        1314.863647   1042.0
# 1728         732.910706    541.0
# 1729         396.789124    337.0
# 1730         320.104431    224.0
# 1731         193.875671    139.0
#
# [1732 rows x 2 columns]

# %%
plt.plot(train_results['Train Predictions'][50:100])
plt.plot(train_results['Actuals'][50:100])

# %%
plt.plot(gru.history['loss'], label='train')
plt.plot(gru.history['val_loss'], label='validation')
plt.legend()
plt.show()

# %%
gru_train_pred = model2.predict(x_train)
gru_test_pred = model2.predict(x_test)
print('Train RMSE:', np.sqrt(mean_squared_error(y_train, gru_train_pred)))
print('Test RMSE:', np.sqrt(mean_squared_error(y_test, gru_test_pred)))
print('MSE:', mean_squared_error(y_test, train_predictions))
print('Explained variance score:', explained_variance_score(y_test, train_predictions))
print('Max error:', max_error(y_test, train_predictions))
# Out:
# 490/490 [==============================] - 1s 2ms/step
# 55/55 [==============================] - 0s 2ms/step
# Train RMSE: 0.11052654952868815
# Test RMSE: 0.16179669451030615
# MSE: 0.026178170354461332
# Explained variance score: 0.9373262292981961
# Max error: 1.1959994276036245

# %% [markdown]
# XGBOOST

# %%
from xgboost.sklearn import XGBRegressor
from sklearn import metrics
import xgboost as xgb

x = df.drop(['cnt'],axis=1)
y = df['cnt']

x_train , x_test , y_train , y_test = train_test_split(x , y , test_size = 0.1 , random_state = 0)

xgb_sklearn = xgb.sklearn.XGBRegressor()
xgb_sklearn.fit(x_train , y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
result = xgb_sklearn.predict(x_test)

# %%
metrics.r2_score(y_test , result)
# Out:
# 0.9513372437569874

# %%
train_predictions4 = xgb_sklearn.predict(x_test)
train_results = pd.DataFrame(data={'Train Predictions':train_predictions4.flatten(), 'Actuals':y_test})

# %%
train_results
# Out:
#                      Train Predictions  Actuals
# timestamp
# 2015-10-06 21:00:00         596.106201      705
# 2015-05-16 21:00:00         836.577576      958
# 2016-10-15 23:00:00         506.572540      497
# 2016-07-19 10:00:00        1303.585083     1392
# 2015-12-01 18:00:00        2479.269531     3073
# ...                                ...      ...
# 2015-06-23 15:00:00        1524.303223     1696
# 2016-02-27 06:00:00         115.981285       92
# 2016-06-16 11:00:00        1249.231201     1125
# 2016-02-21 10:00:00         939.219360      822
# 2015-04-14 10:00:00        1230.885010      990
#
# [1742 rows x 2 columns]

# %%
xgb.plot_importance(xgb_sklearn)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ### END

# %% [markdown]
# ****************************************************************************** END *********************************************************************************
